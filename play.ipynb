# %%
epochs = list(range(12, 0, -1))

loss = [1.0895, 1.1445, 1.1660, 1.1706, 1.1668, 1.1637,
        1.1676, 1.1413, 1.1871, 1.0982, 0.9991, 0.9999]

val_dice_pos = [0.6871, 0.6679, 0.6816, 0.6833, 0.6727, 0.5321,
                0.7048, 0.7251, 0.7478, 0.7845, 0.7879, 0.7873]

val_dice_all = [0.6308, 0.6158, 0.6284, 0.4341, 0.6100, 0.1035,
                0.6500, 0.6733, 0.7154, 0.7337, 0.7399, 0.7395]

val_iou_pos = [0.5234, 0.5014, 0.5169, 0.5190, 0.5068, 0.3625,
               0.5442, 0.5688, 0.5971, 0.6454, 0.6500, 0.6492]

val_iou_all = [0.4607, 0.4449, 0.4582, 0.2772, 0.4389, 0.0546,
               0.4815, 0.5075, 0.5569, 0.5794, 0.5872, 0.5867]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(epochs, loss, marker='o', label="Loss")
plt.plot(epochs, val_dice_pos, marker='o', label="Val Dice Pos")
plt.plot(epochs, val_dice_all, marker='o', label="Val Dice All")
plt.plot(epochs, val_iou_pos, marker='o', label="Val IoU Pos")
plt.plot(epochs, val_iou_all, marker='o', label="Val IoU All")

plt.gca().invert_xaxis()  # so Epoch 1 appears at left / 12 at right

plt.title("Training Metrics vs Epochs (Reversed Order)")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
